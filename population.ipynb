# %% [markdown]
# <a href="https://colab.research.google.com/github/dubussy/insideout/blob/main/population.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ac3f58d6-da70-49ac-a040-6e15c208a926" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac3f58d6-da70-49ac-a040-6e15c208a926">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020korea.csv to 2020korea (3).csv

# %%
#나눔폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Selecting previously unselected package fonts-nanum-eco.
# (Reading database ... 145498 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import matplotlib.font_manager as fm
fm._rebuild()
#런타임 재시작하기

# %%
#2020년 전국 인구 구성 항아리 그래프 (교과서 업데이트)
import csv
f=open('2020korea.csv', encoding = 'cp949')
data = csv.reader(f)
m=[]
f=[]
for row in data:
    if '전국' in row[0]:
        for i in range(0,101):
            m.append(-int(row[i+3].replace(',','')))
            f.append(int(row[-(i+1)].replace(',','')))
f.reverse()

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(11,6),dpi=300)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title('전국 남녀 성별 인구 분포')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f,label='여성')
plt.legend()
plt.show()

# %%
#2020년 시도 인구 구성 항아리 그래프 (지역별 차이)
import csv
f=open('2020korea.csv', encoding = 'cp949')
data = csv.reader(f)
m=[]
f=[]
name=input('원하는 시도명을 입력해주세요:')   # name 변수 입력해보기 
for row in data:
    if name in row[0]:
        for i in range(0,101):
            m.append(-int(row[i+3].replace(',','')))
            f.append(int(row[-(i+1)].replace(',','')))
f.reverse()

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(11,6),dpi=300)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 남녀 성별 인구 분포')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f,label='여성')
plt.legend()
plt.show()
# Out:
# 원하는 시도명을 입력해주세요:서울

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c72836c5-ec1f-4ab4-ac6a-bcd8f8d03618" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c72836c5-ec1f-4ab4-ac6a-bcd8f8d03618">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020.csv to 2020.csv

# %%
#2020년 동네 인구 구성 항아리 그래프 (학생들 관심)
import csv
f=open('2020.csv', encoding = 'cp949')
data=csv.reader(f)
m=[]
f=[]
name=input('원하는 동네명을 입력해주세요:')   
for row in data:
    if name in row[0]:
        for i in range(0,101):
            m.append(-int(row[i+3].replace(',','')))
            f.append(int(row[-(i+1)].replace(',','')))
f.reverse()

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(11,6),dpi=300)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 남녀 성별 인구 분포')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f,label='여성')
plt.legend()
plt.show()
# Out:
# 원하는 동네명을 입력해주세요:목5동

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5aa1ea31-a76f-4a82-a623-79096549baed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5aa1ea31-a76f-4a82-a623-79096549baed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2010korea.csv to 2010korea (1).csv

# %%
#2010년 전국 인구 구성 항아리 그래프 (저출산 고령화)
import csv
f=open('2010korea.csv', encoding = 'cp949')
data=csv.reader(f)
m=[]
f=[]
name=input('원하는 시도명을 입력해주세요:')   
for row in data:
    if name in row[0]:
        for i in range(0,101):
            m.append(-int(row[i+3].replace(',','')))
            f.append(int(row[-(i+1)].replace(',','')))
f.reverse()

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(11,6),dpi=300)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 남녀 성별 인구 분포')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f,label='여성')
plt.legend()
plt.show()
# Out:
# 원하는 시도명을 입력해주세요:전국

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8e958093-088c-479a-b445-e0d006eb5ada" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e958093-088c-479a-b445-e0d006eb5ada">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2010town.csv to 2010town.csv

# %%
#2010년 동네 인구 구성 항아리 그래프 (저출산 고령화)
import csv
f=open('2010town.csv', encoding = 'cp949')
data=csv.reader(f)
m=[]
f=[]
name=input('원하는 동네명을 입력해주세요:')   
for row in data:
    if name in row[0]:
        for i in range(0,101):
            m.append(-int(row[i+3].replace(',','')))
            f.append(int(row[-(i+1)].replace(',','')))
f.reverse()

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(11,6),dpi=300)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 남녀 성별 인구 분포')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f,label='여성')
plt.legend()
plt.show()
# Out:
# 원하는 동네명을 입력해주세요:목5동

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-40bb5305-568a-41aa-9e9f-c53062c035b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40bb5305-568a-41aa-9e9f-c53062c035b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020.csv to 2020 (1).csv

# %%
#우리 동네의 저출산 고령화 알아보기(원그래프)
import csv
f=open('2020.csv', encoding = 'cp949')
data=csv.reader(f)
ch=0
ad=0
se=0
size=[]

name=input('알고 싶은 동네를 입력해주세요:')

for row in data:
    if name in row[0]:
        for i in range(3,18):
            ch += int(row[i].replace(',',''))
        for i in range(18,68):
            ad += int(row[i].replace(',',''))
        for i in range(68,104):
            se += int(row[i].replace(',',''))
size.append(ch)
size.append(ad)
size.append(se)

import matplotlib.pyplot as plt
plt.figure(figsize=(10,5),dpi=300)
plt.rc('font', family='NanumGothic')
color=['lime','royalblue','yellow']
plt.axis('equal')

plt.pie(size, labels=['유소년층','청장년층','노년층'], autopct='%.1f%%', colors=color)
plt.title(name+' 지역의 인구 구성 비율')
plt.show()
# Out:
# 알고 싶은 동네를 입력해주세요:등촌제3동

# %%
#(심화)인구 구성이 비슷한 곳
import numpy as np
np.seterr(divide='ignore', invalid='ignore')
import csv
f=open('2020.csv', encoding='cp949')
data=csv.reader(f)
next(data)
data=list(data)

name=input('궁금한 동네 이름 입력: ')
mn=1
result_name=''
result=0

for row in data:
    if name in row[0]:
        for i in range(0,len(row[0:])):
            row[i]=row[i].replace(',','')
        home=np.array(row[3:],dtype=int)/int(row[2])
for row in data:
    for i in range(0,len(row[0:])):
            row[i]=row[i].replace(',','')
    away=np.array(row[3:],dtype=int)/int(row[2])
    s=np.sum(abs(home-away))
    if s<mn and name not in row[0]:
        mn=s
        result_name=row[0]
        result=away
                
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(11,6), dpi=300)
plt.rc('font',family='NanumGothic')
plt.title(name+' 지역과 가장 비슷한 인구 구조를 가진 지역')
plt.plot(home, label=name)
plt.plot(result,label=result_name)
plt.legend()
plt.show()
# Out:
# 궁금한 동네 이름 입력: 등촌제3동

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-75a93a7c-2b90-4a36-aa99-edb905d64a0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75a93a7c-2b90-4a36-aa99-edb905d64a0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020gu.csv to 2020gu.csv

# %%
#(심화)인구 구성이 비슷한 지역구
import numpy as np
np.seterr(divide='ignore', invalid='ignore')
import csv
f=open('2020gu.csv', encoding='cp949')
data=csv.reader(f)
next(data)
data=list(data)

name=input('궁금한 시.군.구 이름 입력: ')   #이름 변경
mn=1
result_name=''
result=0

for row in data:
    if name in row[0]:
        for i in range(0,len(row[0:])):
            row[i]=row[i].replace(',','')
        home=np.array(row[3:],dtype=int)/int(row[2])
for row in data:
    for i in range(0,len(row[0:])):
            row[i]=row[i].replace(',','')
    away=np.array(row[3:],dtype=int)/int(row[2])
    s=np.sum(abs(home-away))
    if s<mn and name not in row[0]:
        mn=s
        result_name=row[0]
        result=away
                
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(11,6), dpi=300)
plt.rc('font',family='NanumGothic')
plt.title(name+' 지역과 가장 비슷한 인구 구조를 가진 지역')
plt.plot(home, label=name)
plt.plot(result,label=result_name)
plt.legend()
plt.show()
# Out:
# 궁금한 시.군.구 이름 입력: 양천구

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-978d1169-6268-4f6b-8efc-28b6029a67ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-978d1169-6268-4f6b-8efc-28b6029a67ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving elementary.csv to elementary.csv

# %%
#(심화)최근 5년간 초등학생 인구가 가장 감소한 지역구는?(꺾은선 그래프)
import csv
f=open('elementary.csv', encoding='cp949')
data=csv.reader(f)
name=input('알고싶은 구 이름을 입력하세요:')
result=[]
gap=0

for row in data:
    if name in row[0]:
        for i in row[1:]:
            result.append(int(i.replace(',','')))
        gap=int(row[-1].replace(',',''))-int(row[1].replace(',',''))
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rc('font',family='NanumGothic')
plt.title(name+' 지역의 최근 5년간 초등학생수 변화')
plt.xticks(range(5),['2016','2017','2018','2019','2020'])
plt.xlabel('연도')
plt.ylabel('학생수')
plt.plot(result)
plt.show()
print('학생수 차이(명):',gap)
# Out:
# 알고싶은 구 이름을 입력하세요:강서구
# 학생수 차이(명): -1335

# %%
#(심화)최근 5년간 초등학생 인구가 가장 감소한 지역구는?(꺾은선 그래프)-Flourish로 비교
