# %% [markdown]
# <a href="https://colab.research.google.com/github/dubussy/insideout/blob/main/%EC%9D%B8%EA%B5%AC%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%8B%A4%EC%8A%B5(%EC%99%84%EC%84%B1%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  <단축키>
#
# *   ctrl + enter  : 셀 실행
# *   shift + enter : 셀 실행 후 다음 셀로 이동
# *   주석 쓰기  : # 또는 ctrl + /
# *   A : 위(Above)에 셀 추가
# *   B : 아래(Below)에 셀 추가

# %%
# 한글 나눔폰트 설치
# !apt-get update -qq  
# !apt-get install fonts-nanum* -qq

# %%
import matplotlib.font_manager as fm
fm._rebuild()
#실행 후 런타임 - 런타임 다시 시작하기

# %% [markdown]
# ** 다운받은 데이터 파일 모두 업로드

# %%
from google.colab import files 
uploaded = files.upload()
# 다운로드한 파일 모두 선택하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <2020년 12월 전국 **시도** 남녀 1세~100세 이상 연령별 인구 데이터 사용>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #1. 2020년 전국 인구 피라미드 그래프 (교과서 업데이트)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# STEP1. CSV 파일 불러오기   (파일명: '202012korea.csv')         
import csv
f = open('202012korea.csv', encoding='cp949')
data = csv.reader(f)

# STEP2. 남성, 여성 데이터를 담을 리스트 만들기
m = []
f = []

# STEP3. for 반복문으로 남여 연령별 인구수 데이터 저장하기 
for row in data : 
    if '전국' in row[0] : 
        for i in row[3:104] :
            m.append(-int(i))
        for i in row[106: ] :
            f.append(int(i))

# %%
# STEP4. matplotlib으로 막대그래프 그리기
import matplotlib.pyplot as plt
plt.barh(range(101),m)
plt.barh(range(101), f)
plt.show()

# %%
# STEP5. 그래프 오류 수정하기

# %%
# STEP6. 그래프 꾸미기 (제목, 범례, 크기, 스타일 등)
plt.style.use('ggplot')                                               # 배경 스타일 선택 (bmh, fast, dark_background, fivethirtyeight 등)
plt.figure(figsize=(11,6),dpi=300)                            # 그래프 크기와 해상도
plt.rc('font', family='NanumGothic')                         # 글꼴
plt.rcParams['axes.unicode_minus']=False            # 마이너스(-)부호 깨짐 방지
plt.title('2020년 전국 인구 피라미드 그래프')              # 그래프 제목
plt.barh(range(101), m, label='남성')                      # 막대 그래프 그리기 
plt.barh(range(101), f, label='여성')
plt.legend()                                                                            # 범례 표시
plt.show()

# %% [markdown]
# #2. 2020년 시도 인구 피라미드 그래프 (지역별 차이 알아보기)

# %%
# 2020년 시도 인구 피라미드 그래프 (지역별 차이 알아보기)
import csv
f=open('202012korea.csv', encoding = 'cp949')
data = csv.reader(f)
m=[]
f=[]
name = input('원하는 시도명을 입력하세요(예.충청북도) : ')     # input 함수 입력해보기 
for row in data:
    if name in row[0]:
        for  i in row[3:104]:
            m.append(-int(i))
        for  i in row[106:]:
             f.append(int(i))

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(11,6),dpi=300)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 남녀 성별 인구 분포(2020년)')                 # 검색한 시도명이 제목에 나오도록 하기 
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f,label='여성')
plt.legend()
plt.show()

# %% [markdown]
# <2020년 12월 전국 **읍면동** 남녀 0세~100세 이상 연령별 인구 데이터 사용>

# %% [markdown]
# #3. 2020년 동네 인구피라미드 그래프 (학생들이 사는 동네 관심 유발하기)

# %%
# 2020년 동네 인구피라미드 그래프 (학생들이 사는 동네 관심 유발하기)
import csv
f=open('202012town.csv', encoding = 'cp949')
data=csv.reader(f)
m=[]
f=[]
name=input('원하는 동네명을 입력해주세요:')   
for row in data:
    if name in row[0]:
        for  i in row[3:104]:
            m.append(-int(i))
        for  i in row[106:]:
             f.append(int(i))

import matplotlib.pyplot as plt
plt.style.use('ggplot')                                        
plt.figure(figsize=(11,6),dpi=300)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 남녀 성별 인구 분포(2020년)')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f, label='여성')
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <2010년 전국 **시도** 남녀 1세~100세 이상 연령별 인구 데이터 사용>

# %% [markdown]
# #4. 2010년 전국 인구 피라미드 그래프 (저출산 고령화 알아보기)

# %%
# 2010년 전국 인구 피라미드 그래프 그려보기
import csv
f=open('2010korea.csv', encoding = 'cp949')
data=csv.reader(f)
m=[]
f=[]
name=input('원하는 시도명을 입력해주세요:')   
for row in data:
    if name in row[0]:
        for  i in row[3:104]:
            m.append(-int(i))
        for  i in row[106:]:
             f.append(int(i))

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(6,4),dpi=100)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 남녀 성별 인구 분포(2010년)')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f,label='여성')
plt.legend()
plt.show()

# %%
# 2020년 전국 인구 피라미드 그래프와 비교해보기
import csv
f=open('202012korea.csv', encoding = 'cp949')
data = csv.reader(f)
m=[]
f=[]
for row in data:
    if '전국' in row[0]:
        for  i in row[3:104]:
            m.append(-int(i))
        for  i in row[106:]:
             f.append(int(i))

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(6,4),dpi=100)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title('전국 남녀 성별 인구 분포(2020년)')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f,label='여성')
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <2010년 전국 **읍면동** 남녀 1세~100세 이상 연령별 인구 데이터 사용>

# %% [markdown]
# #5. 2010년 우리 동네 인구피라미드 그래프 (저출산 고령화)

# %%
#5. 2010년 우리 동네 인구피라미드 그래프 그려보기
import csv
f=open('2010town.csv', encoding = 'cp949')
data=csv.reader(f)
m=[]
f=[]
name=input('원하는 동네명을 입력해주세요:')   
for row in data:
    if name in row[0]:
        for  i in row[3:104]:
            m.append(-int(i))
        for  i in row[106:]:
             f.append(int(i))

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(6,4),dpi=100)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 남녀 성별 인구 분포(2010년)')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f, label='여성')
plt.legend()
plt.show()

# %%
#2020년 우리 동네 그래프와 비교하기
import csv
f=open('202012town.csv', encoding = 'cp949')
data=csv.reader(f)
m=[]
f=[]
name=input('원하는 동네명을 입력해주세요:')   
for row in data:
    if name in row[0]:
        for  i in row[3:104]:
            m.append(-int(i))
        for  i in row[106:]:
             f.append(int(i))

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(6,4),dpi=100)
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 남녀 성별 인구 분포(2020년)')
plt.barh(range(101),m, label='남성')
plt.barh(range(101),f, label='여성')
plt.legend()
plt.show()

# %% [markdown]
# <2020년 전국 **읍면동** 0세~100세 이상 연령별 인구 데이터 사용> -남녀구분X 총합

# %% [markdown]
# #6. 우리 동네의 고령화 정도 알아보기(연령별 인구 구성 원그래프 그려보기)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#  (참고) 기준: 노년층 비율 7%이상 - 고령화 사회, 14%이상- 고령 사회, 20%이상- 초고령 사회

# %%
# 파이 차트 기본
import matplotlib.pyplot as plt
size=[10, 30, 25]
plt.pie(size)
plt.show()

# %%
# STEP1. CSV 파일 불러오기 (파일명 '2020age.csv' , encoding='cp949')
import csv
f = open('2020age.csv', encoding='cp949')
data= csv.reader(f)

# STEP2. 변수 만들기 (3개의 연령층 변수,  각각의 크기를 담을 size 리스트)
ch=0
ad=0
se=0
size=[ ]

# STEP3. for 반복문으로 연령층별 인구수 합 구해서 저장하기 (ch-0세~14세 range(3,18) / ad-15세~64세 range(18,68) / se-65세~100세 이상 range(68,104))
for row in data :
    if '목1동' in row[0] : 
        for i in range(3,18) :
            ch += int(row[i])
        for i in range(18,68) :
            ad += int(row[i])
        for i in range(68,104) :
            se += int(row[i])

size.append(ch)
size.append(ad)
size.append(se)

# STEP4. 기본파이차트(원그래프) 그리기 
import matplotlib.pyplot as plt
plt.pie(size)
plt.show()

# %%
#STEP5. 원그래프 꾸미기(크기, 색깔, 레이블, 퍼센트, 제목 등)
plt.figure(figsize=(10,5),dpi=300)
plt.rc('font', family='NanumGothic')
color=['lime','royalblue','yellow']                       # 각각의 색상 순서대로 선택          
plt.axis('equal')                                                # x축, y축 길이 동일하게 
plt.pie(size, explode=(0,0,0.1), labels=['유소년층','청장년층','노년층'], autopct='%.1f%%', colors=color)   # 파이차트(크기, 강조, 레이블, 소수점자리, 색상)
plt.title('우리 동네는 고령 사회일까?')        
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #7. (심화)우리 동네와 인구 구성이 비슷한 동네 찾아보기

# %%
#7. (심화)우리 동네와 인구 구성이 비슷한 동네
import numpy as np
np.seterr(divide='ignore', invalid='ignore')                 
import csv
f=open('2020age.csv', encoding='cp949')
data=csv.reader(f)
next(data)                                                               
data=list(data)

name=input('궁금한 동네 이름 입력: ')
mn=1
result_name=''
result=0

for row in data:
    if name in row[0]:
        for i in range(0,len(row[0:])):
            row[i]=row[i].replace(',','')
        home=np.array(row[3:],dtype=int)/int(row[2])
for row in data:
    for i in range(0,len(row[0:])):
            row[i]=row[i].replace(',','')
    away=np.array(row[3:],dtype=int)/int(row[2])
    s=np.sum(abs(home-away))
    if s<mn and name not in row[0]:
        mn=s
        result_name=row[0]
        result=away
                
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(11,6), dpi=300)
plt.rc('font',family='NanumGothic')
plt.title(name+' 지역과 가장 비슷한 인구 구조를 가진 지역')
plt.plot(home, label=name)
plt.plot(result,label=result_name)
plt.legend()
plt.show()

# %% [markdown]
# <2020년 전국 **시군구** 0세~100세 이상 연령별 인구 데이터 사용> -남녀구분X 총합

# %% [markdown]
# #8.(심화)인구 구성이 비슷한 지역(시군구) 찾아보기

# %%
#8.(심화)인구 구성이 비슷한 지역구 찾아보기
import numpy as np
np.seterr(divide='ignore', invalid='ignore')
import csv
f=open('2020gu.csv', encoding='cp949')
data=csv.reader(f)
next(data)
data=list(data)

name=input('궁금한 시.군.구 이름을 입력하세요(예.종로구): ')  
mn=1
result_name=''
result=0

for row in data:
    if name in row[0]:
        for i in range(0,len(row[0:])):
            row[i]=row[i].replace(',','')
        home=np.array(row[3:],dtype=int)/int(row[2])
for row in data:
    for i in range(0,len(row[0:])):
            row[i]=row[i].replace(',','')
    away=np.array(row[3:],dtype=int)/int(row[2])
    s=np.sum(abs(home-away))
    if s<mn and name not in row[0]:
        mn=s
        result_name=row[0]
        result=away
                
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(11,6), dpi=300)
plt.rc('font',family='NanumGothic')
plt.title(name+' 지역과 가장 비슷한 인구 구조를 가진 지역')
plt.plot(home, label=name)
plt.plot(result,label=result_name)
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <2016 - 2020년 **서울 자치구별** 만7세~12세(초등학생) 인구 합계 데이터 사용>

# %% [markdown]
# #9.(심화)우리 동네(구)의 초등학생은 정말 감소했을까?(꺾은선 그래프)

# %%
#9.(심화)우리 동네(구)의 초등학생은 정말 감소했을까?(꺾은선 그래프)
import csv
f=open('elementary.csv', encoding='cp949')
data=csv.reader(f)
name=input('알고싶은 구 이름을 입력하세요:')
result=[]
gap=0                                                                              #2020년과 2016년의 초등학생 인구수 차이 

for row in data:
    if name in row[0]:
        for i in row[1:]:
            result.append(int(i))
        gap=int(row[-1])-int(row[1])

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rc('font',family='NanumGothic')
plt.title(name+' 지역의 최근 5년간 초등학생수 변화')
plt.xticks(range(5),['2016','2017','2018','2019','2020'])    # x축 눈금
plt.xlabel('연도')
plt.ylabel('학생수')
plt.plot(result)                                                                  # 꺾은선 그래프 그리기 
plt.show()
print('학생수 차이(명):',gap)

# %% [markdown]
# #10. (심화)최근 5년간 초등학생 인구가 가장 감소한 구는 어디일까?

# %%
#10. (심화)최근 5년간 초등학생 인구가 가장 감소한 구는?(꺾은선 그래프)-Flourish로 비교

# %% [markdown]
# https://public.flourish.studio/visualisation/4835652/
